# %%
# Import of required modules
import pandas as pd
from statsmodels.tsa.ar_model import AR
from sklearn.model_selection import train_test_split

# Manually defined format of reading dates
dateparse = lambda dates: pd.datetime.strptime(dates, '%d/%m/%Y')

# Reading Purchase Order table from database, converting column containing date to datetime format recognised by Python
df1 = pd.read_csv('PurchaseOrder.2.csv', parse_dates=['Order_Date'], index_col='Order_Date',date_parser=dateparse)

# Reading Purchase Order Details and Catalogue table from database
df2 = pd.read_csv('PurchaseOrderDetails.2.csv')
df3 = pd.read_csv('Catalogue(Raw).csv')

df = df1.reset_index().merge(df2)

# Storing of unique item names
uniqueitem = df['Item_Num'].unique()

# Creation of empty array for predictions made by ML
predictions = {}

# For each item stored in line 9, to conduct ML process
for id in range(0, len(uniqueitem)):
    df2 = df.loc[df['Item_Num'] == uniqueitem[id]]
    ts = df2[['Order_Date','Quantity']]
    ts.Order_Date = pd.to_datetime(ts.Order_Date)
    ts.set_index('Order_Date', inplace=True)
    
    # Summarising ‘Quantity’ values on a monthly level
    ts = ts.resample('MS').sum()
    X = ts.values
    
    # Setting training size to utilise full 12 months’ worth of data
    train, test = train_test_split(X, test_size = 0, random_state = 0)
    model = AR(train)
    model_fit = model.fit()
    
    # Retrieving one-step-ahead forecast based on training data
    prediction = model_fit.predict(start=len(train), end=len(train)+len(test))
    
    # Saving predictions made by item name in a dictionary
    predictions.update( {uniqueitem[id] : prediction[0]} )
    
# Creating a column containing prediction values
df3['Predicted_Quantity'] = df3.Item_Num.map(predictions)

# Storing predicted values back into Catalogue table, to be inserted into database
df3.to_csv("Catalogue.csv", index=False)
# Out:
#    Item_Num   Category                          Description  Reorder_Level  \
# 0      C001       Clip                      Clips Double 1"             50
# 1      C002       Clip                      Clips Double 2"             50
# 2      C003       Clip                    Clips Double 3/4"             50
# 3      C004       Clip                    Clips Paper Large             50
# 4      C005       Clip                   Clips Paper Medium             50
# 5      C006       Clip                    Clips Paper Small             50
# 6      E001   Envelope               Envelope Brown (3"x6")            600
# 7      E002   Envelope     Envelope Brown (3"x6") w/ Window            600
# 8      E003   Envelope               Envelope Brown (5"x7")            600
# 9      E004   Envelope     Envelope Brown (5"x7") w/ Window            600
# 10     E005   Envelope               Envelope White (3"x6")            600
# 11     E006   Envelope     Envelope White (3"x6") w/ Window            600
# 12     E007   Envelope               Envelope White (5"x7")            600
# 13     E008   Envelope     Envelope White (5"x7") w/ Window            600
# 14     E020     Eraser                        Eraser (hard)             50
# 15     E021     Eraser                        Eraser (soft)             50
# 16     E030   Exercise               Exercise Book (100 pg)            100
# 17     E031   Exercise               Exercise Book (120 pg)            100
# 18     E032   Exercise  Exercise Book A4 Hardcover (100 pg)            100
# 19     E033   Exercise  Exercise Book A4 Hardcover (120 pg)            100
# 20     E034   Exercise  Exercise Book A4 Hardcover (200 pg)            100
# 21     E035   Exercise     Exercise Book Hardcover (100 pg)            100
# 22     E036   Exercise     Exercise Book Hardcover (120 pg)            100
# 23     F020       File                       File Separator            100
# 24     F021       File                      File-Blue Plain            200
# 25     F022       File                  File-Blue with Logo            200
# 26     F023       File                  File-Brown w/o Logo            200
# 27     F024       File                 File-Brown with Logo            200
# 28     F031       File                  Folder Plastic Blue            200
# 29     F032       File                 Folder Plastic Clear            200
# ..      ...        ...                                  ...            ...
# 59     P040        Pen          Pen Whiteboard Marker Green            100
# 60     P041        Pen            Pen Whiteboard Marker Red            100
# 61     P042        Pen                            Pencil 2B            100
# 62     P043        Pen            Pencil 2B with Eraser End            100
# 63     P044        Pen                            Pencil 4H            100
# 64     P045        Pen                             Pencil B            100
# 65     P046        Pen             Pencil B with Eraser End            100
# 66     R001      Ruler                             Ruler 6"             50
# 67     R002      Ruler                            Ruler 12"             50
# 68     S010  Shorthand              Shorthand Book (100 pg)            100
# 69     S011  Shorthand              Shorthand Book (120 pg)            100
# 70     S012  Shorthand               Shorthand Book (80 pg)            100
# 71     S020    Stapler                       Stapler No. 28             50
# 72     S021    Stapler                       Stapler No. 36             50
# 73     S022    Stapler                       Stapler No. 28             50
# 74     S023    Stapler                       Stapler No. 36             50
# 75     S040       Tape                          Scotch Tape             50
# 76     S041       Tape                Scotch Tape Dispenser             50
# 77     S100   Scissors                             Scissors             50
# 78     S101  Sharpener                            Sharpener             50
# 79     T001      Tacks                    Thumb Tacks Large             10
# 80     T002      Tacks                   Thumb Tacks Medium             10
# 81     T003      Tacks                    Thumb Tacks Small             10
# 82     T020   Tparency                    Transparency Blue            100
# 83     T021   Tparency                   Transparency Clear            500
# 84     T022   Tparency                   Transparency Green            100
# 85     T023   Tparency                     Transparency Red            100
# 86     T024   Tparency            Transparency Reverse Blue            100
# 87     T025   Tparency                Transparency Cover 3M            500
# 88     T100       Tray                         Trays In/Out             20
#
#     Reorder_Quantity  Predicted_Quantity  Available_Quantity    UOM  Price  \
# 0                 30         1258.666763                 500  Dozen     20
# 1                 30          984.469947                 500  Dozen     20
# 2                 30         1130.309504                 500  Dozen     20
# 3                 30          741.022588                 500    Box     20
# 4                 30         1414.619570                 500    Box     20
# 5                 30         1044.033419                 500    Box     20
# 6                400          943.718643                 500   Each     20
# 7                400         1521.414809                 500   Each     20
# 8                400          969.760110                 500   Each     20
# 9                400         1115.073801                 500   Each     20
# 10               400         1016.552598                 500   Each     20
# 11               400         1132.259972                 500   Each     20
# 12               400         1077.908422                 500   Each     20
# 13               400         1489.962241                 500   Each     20
# 14                20         1077.579903                 500   Each     20
# 15                20          997.703778                 500   Each     20
# 16                50         1132.563948                 500   Each     20
# 17                50         1290.255678                 500   Each     20
# 18                50         1389.127593                 500   Each     20
# 19                50         1122.599062                 500   Each     20
# 20                50          519.689237                 500   Each     20
# 21                50         1021.956623                 500   Each     20
# 22                50         1195.351183                 500   Each     20
# 23                50         1316.965974                 500    Set     20
# 24               100         1378.340744                 500   Each     20
# 25               100        -1525.448162                 500   Each     20
# 26               150         1014.465379                 500   Each     20
# 27               150         1239.283427                 500   Each     20
# 28               150         1016.537263                 500   Each     20
# 29               150         1568.156315                 500   Each     20
# ..               ...                 ...                 ...    ...    ...
# 59                50         1060.183291                 500    Box     20
# 60                50         1348.483352                 500    Box     20
# 61                50          435.719095                 500  Dozen     20
# 62                50          978.191161                 500  Dozen     20
# 63                50         1001.474050                 500  Dozen     20
# 64                50         1188.016034                 500  Dozen     20
# 65                50         1226.284859                 500  Dozen     20
# 66                20         1208.532919                 500  Dozen     20
# 67                20         1005.535235                 500  Dozen     20
# 68                80         2114.164854                 500   Each     20
# 69                80         1155.390458                 500   Each     20
# 70                80         1409.803747                 500   Each     20
# 71                20          844.232618                 500   Each     20
# 72                20         1084.659713                 500   Each     20
# 73                20          305.762271                 500    Box     20
# 74                20         1077.401316                 500    Box     20
# 75                20         1049.129492                 500   Each     20
# 76                20         1402.142433                 500   Each     20
# 77                20         1307.303401                 500   Each     20
# 78                20         1125.108716                 500   Each     20
# 79                10         1735.963256                 500    Box     20
# 80                10          958.083471                 500    Box     20
# 81                10          998.135752                 500    Box     20
# 82               200         1166.582822                 500    Box     20
# 83               400         1039.493991                 500    Box     20
# 84               200         1088.327294                 500    Box     20
# 85               200         1050.596172                 500    Box     20
# 86               200          408.412522                 500    Box     20
# 87               400         1119.409669                 500    Box     20
# 88                10          853.903763                 500    Set     20
#
#     Bin_Number  Supplier_1  Supplier_2  Supplier_3
# 0          NaN         NaN         NaN         NaN
# 1          NaN         NaN         NaN         NaN
# 2          NaN         NaN         NaN         NaN
# 3          NaN         NaN         NaN         NaN
# 4          NaN         NaN         NaN         NaN
# 5          NaN         NaN         NaN         NaN
# 6          NaN         NaN         NaN         NaN
# 7          NaN         NaN         NaN         NaN
# 8          NaN         NaN         NaN         NaN
# 9          NaN         NaN         NaN         NaN
# 10         NaN         NaN         NaN         NaN
# 11         NaN         NaN         NaN         NaN
# 12         NaN         NaN         NaN         NaN
# 13         NaN         NaN         NaN         NaN
# 14         NaN         NaN         NaN         NaN
# 15         NaN         NaN         NaN         NaN
# 16         NaN         NaN         NaN         NaN
# 17         NaN         NaN         NaN         NaN
# 18         NaN         NaN         NaN         NaN
# 19         NaN         NaN         NaN         NaN
# 20         NaN         NaN         NaN         NaN
# 21         NaN         NaN         NaN         NaN
# 22         NaN         NaN         NaN         NaN
# 23         NaN         NaN         NaN         NaN
# 24         NaN         NaN         NaN         NaN
# 25         NaN         NaN         NaN         NaN
# 26         NaN         NaN         NaN         NaN
# 27         NaN         NaN         NaN         NaN
# 28         NaN         NaN         NaN         NaN
# 29         NaN         NaN         NaN         NaN
# ..         ...         ...         ...         ...
# 59         NaN         NaN         NaN         NaN
# 60         NaN         NaN         NaN         NaN
# 61         NaN         NaN         NaN         NaN
# 62         NaN         NaN         NaN         NaN
# 63         NaN         NaN         NaN         NaN
# 64         NaN         NaN         NaN         NaN
# 65         NaN         NaN         NaN         NaN
# 66         NaN         NaN         NaN         NaN
# 67         NaN         NaN         NaN         NaN
# 68         NaN         NaN         NaN         NaN
# 69         NaN         NaN         NaN         NaN
# 70         NaN         NaN         NaN         NaN
# 71         NaN         NaN         NaN         NaN
# 72         NaN         NaN         NaN         NaN
# 73         NaN         NaN         NaN         NaN
# 74         NaN         NaN         NaN         NaN
# 75         NaN         NaN         NaN         NaN
# 76         NaN         NaN         NaN         NaN
# 77         NaN         NaN         NaN         NaN
# 78         NaN         NaN         NaN         NaN
# 79         NaN         NaN         NaN         NaN
# 80         NaN         NaN         NaN         NaN
# 81         NaN         NaN         NaN         NaN
# 82         NaN         NaN         NaN         NaN
# 83         NaN         NaN         NaN         NaN
# 84         NaN         NaN         NaN         NaN
# 85         NaN         NaN         NaN         NaN
# 86         NaN         NaN         NaN         NaN
# 87         NaN         NaN         NaN         NaN
# 88         NaN         NaN         NaN         NaN
#
# [89 rows x 13 columns]
